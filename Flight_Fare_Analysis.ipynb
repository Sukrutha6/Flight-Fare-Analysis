# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukrutha6/Flight-Fare-Analysis/blob/main/Flight_Fare_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content')

# %%
os.getcwd()
# Out:
# '/content'

# %%
data=pd.read_excel('Flight_Fare.xlsx')

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
data.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# # **Exploratory Data Analysis**
#
# Bivariate Analysis

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data['Route'].fillna(method ='ffill', inplace = True)

# %%
data['Total_Stops'].fillna(method ='ffill', inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
sns.barplot(x='Source',y='Price',data=data)
# Out:
# <Axes: xlabel='Source', ylabel='Price'>

# %%
sns.barplot(x='Destination', y='Price',data=data)
# Out:
# <Axes: xlabel='Destination', ylabel='Price'>

# %%
sns.barplot(x='Total_Stops', y='Price', data=data)
# Out:
# <Axes: xlabel='Total_Stops', ylabel='Price'>

# %%
data.Airline.value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
data1=data[['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
       'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
       'Additional_Info']]

# %%
plt.subplots(figsize=(16,8))
sns.countplot(x='Airline', data=data, ec='black', palette='Set1', order=data['Airline'].value_counts().index)
plt.title('Flight Fare', weight='bold', fontsize=20, pad=20)
plt.ylabel('Count', weight='bold', fontsize=20)
plt.xlabel('Airline', weight='bold', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %%
## Creating the list of categorica; columns

category = ['Airline','Source','Destination','Additional_Info']

# %%
#3 checking unique values in Airline columns

for i in category:
    print(i, data[i].unique())
    print('---------------------------------------')
# Out:
# Airline ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
# ---------------------------------------
# Source ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# ---------------------------------------
# Destination ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']
# ---------------------------------------
# Additional_Info ['No info' 'In-flight meal not included' 'No check-in baggage included'
#  '1 Short layover' 'No Info' '1 Long layover' 'Change airports'
#  'Business class' 'Red-eye flight' '2 Long layover']
# ---------------------------------------

# %%
# Teating the Date column

data.Date_of_Journey = data.Date_of_Journey.str.split('/')

# %%
data.Date_of_Journey
# Out:
# 0        [24, 03, 2019]
# 1         [1, 05, 2019]
# 2         [9, 06, 2019]
# 3        [12, 05, 2019]
# 4        [01, 03, 2019]
#               ...
# 10678     [9, 04, 2019]
# 10679    [27, 04, 2019]
# 10680    [27, 04, 2019]
# 10681    [01, 03, 2019]
# 10682     [9, 05, 2019]
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
data['Date'] = data.Date_of_Journey.str[0]
data['Month'] = data.Date_of_Journey.str[1]
data['Year'] = data.Date_of_Journey.str[2]

# %%
data.Total_Stops.unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
data.Route.unique()
# Out:
# array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#        'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#        'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
#        'MAA → CCU', 'CCU → BOM → BLR', 'DEL → AMD → BOM → COK',
#        'DEL → PNQ → COK', 'DEL → CCU → BOM → COK', 'BLR → COK → DEL',
#        'DEL → IDR → BOM → COK', 'DEL → LKO → COK',
#        'CCU → GAU → DEL → BLR', 'DEL → NAG → BOM → COK',
#        'CCU → MAA → BLR', 'DEL → HYD → COK', 'CCU → HYD → BLR',
#        'DEL → COK', 'CCU → DEL → BLR', 'BLR → BOM → AMD → DEL',
#        'BOM → DEL → HYD', 'DEL → MAA → COK', 'BOM → HYD',
#        'DEL → BHO → BOM → COK', 'DEL → JAI → BOM → COK',
#        'DEL → ATQ → BOM → COK', 'DEL → JDH → BOM → COK',
#        'CCU → BBI → BOM → BLR', 'BLR → MAA → DEL',
#        'DEL → GOI → BOM → COK', 'DEL → BDQ → BOM → COK',
#        'CCU → JAI → BOM → BLR', 'CCU → BBI → BLR', 'BLR → HYD → DEL',
#        'DEL → TRV → COK', 'CCU → IXR → DEL → BLR',
#        'DEL → IXU → BOM → COK', 'CCU → IXB → BLR',
#        'BLR → BOM → JDH → DEL', 'DEL → UDR → BOM → COK',
#        'DEL → HYD → MAA → COK', 'CCU → BOM → COK → BLR',
#        'BLR → CCU → DEL', 'CCU → BOM → GOI → BLR',
#        'DEL → RPR → NAG → BOM → COK', 'DEL → HYD → BOM → COK',
#        'CCU → DEL → AMD → BLR', 'CCU → PNQ → BLR',
#        'BLR → CCU → GAU → DEL', 'CCU → DEL → COK → BLR',
#        'BLR → PNQ → DEL', 'BOM → JDH → DEL → HYD',
#        'BLR → BOM → BHO → DEL', 'DEL → AMD → COK', 'BLR → LKO → DEL',
#        'CCU → GAU → BLR', 'BOM → GOI → HYD', 'CCU → BOM → AMD → BLR',
#        'CCU → BBI → IXR → DEL → BLR', 'DEL → DED → BOM → COK',
#        'DEL → MAA → BOM → COK', 'BLR → AMD → DEL', 'BLR → VGA → DEL',
#        'CCU → JAI → DEL → BLR', 'CCU → AMD → BLR',
#        'CCU → VNS → DEL → BLR', 'BLR → BOM → IDR → DEL',
#        'BLR → BBI → DEL', 'BLR → GOI → DEL', 'BOM → AMD → ISK → HYD',
#        'BOM → DED → DEL → HYD', 'DEL → IXC → BOM → COK',
#        'CCU → PAT → BLR', 'BLR → CCU → BBI → DEL',
#        'CCU → BBI → HYD → BLR', 'BLR → BOM → NAG → DEL',
#        'BLR → CCU → BBI → HYD → DEL', 'BLR → GAU → DEL',
#        'BOM → BHO → DEL → HYD', 'BOM → JLR → HYD',
#        'BLR → HYD → VGA → DEL', 'CCU → KNU → BLR',
#        'CCU → BOM → PNQ → BLR', 'DEL → BBI → COK',
#        'BLR → VGA → HYD → DEL', 'BOM → JDH → JAI → DEL → HYD',
#        'DEL → GWL → IDR → BOM → COK', 'CCU → RPR → HYD → BLR',
#        'CCU → VTZ → BLR', 'CCU → DEL → VGA → BLR',
#        'BLR → BOM → IDR → GWL → DEL', 'CCU → DEL → COK → TRV → BLR',
#        'BOM → COK → MAA → HYD', 'BOM → NDC → HYD', 'BLR → BDQ → DEL',
#        'CCU → BOM → TRV → BLR', 'CCU → BOM → HBX → BLR',
#        'BOM → BDQ → DEL → HYD', 'BOM → CCU → HYD',
#        'BLR → TRV → COK → DEL', 'BLR → IDR → DEL',
#        'CCU → IXZ → MAA → BLR', 'CCU → GAU → IMF → DEL → BLR',
#        'BOM → GOI → PNQ → HYD', 'BOM → BLR → CCU → BBI → HYD',
#        'BOM → MAA → HYD', 'BLR → BOM → UDR → DEL',
#        'BOM → UDR → DEL → HYD', 'BLR → VGA → VTZ → DEL',
#        'BLR → HBX → BOM → BHO → DEL', 'CCU → IXA → BLR',
#        'BOM → RPR → VTZ → HYD', 'BLR → HBX → BOM → AMD → DEL',
#        'BOM → IDR → DEL → HYD', 'BOM → BLR → HYD', 'BLR → STV → DEL',
#        'CCU → IXB → DEL → BLR', 'BOM → JAI → DEL → HYD',
#        'BOM → VNS → DEL → HYD', 'BLR → HBX → BOM → NAG → DEL',
#        'BLR → BOM → IXC → DEL', 'BLR → CCU → BBI → HYD → VGA → DEL',
#        'BOM → BBI → HYD'], dtype=object)

# %%
data.drop(['Route','Additional_Info'], axis=1, inplace = True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo  [24, 03, 2019]  Banglore   New Delhi    22:20
# 1        Air India   [1, 05, 2019]   Kolkata    Banglore    05:50
# 2      Jet Airways   [9, 06, 2019]     Delhi      Cochin    09:25
# 3           IndiGo  [12, 05, 2019]   Kolkata    Banglore    18:05
# 4           IndiGo  [01, 03, 2019]  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia   [9, 04, 2019]   Kolkata    Banglore    19:55
# 10679    Air India  [27, 04, 2019]   Kolkata    Banglore    20:45
# 10680  Jet Airways  [27, 04, 2019]  Banglore       Delhi    08:20
# 10681      Vistara  [01, 03, 2019]  Banglore   New Delhi    11:30
# 10682    Air India   [9, 05, 2019]     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price Date Month  Year
# 0      01:10 22 Mar   2h 50m    non-stop   3897   24    03  2019
# 1             13:15   7h 25m     2 stops   7662    1    05  2019
# 2      04:25 10 Jun      19h     2 stops  13882    9    06  2019
# 3             23:30   5h 25m      1 stop   6218   12    05  2019
# 4             21:35   4h 45m      1 stop  13302   01    03  2019
# ...             ...      ...         ...    ...  ...   ...   ...
# 10678         22:25   2h 30m    non-stop   4107    9    04  2019
# 10679         23:20   2h 35m    non-stop   4145   27    04  2019
# 10680         11:20       3h    non-stop   7229   27    04  2019
# 10681         14:10   2h 40m    non-stop  12648   01    03  2019
# 10682         19:15   8h 20m     2 stops  11753    9    05  2019
#
# [10683 rows x 12 columns]

# %%
#Treating dep time column

data.Dep_Time = data.Dep_Time.str.split(':')

data['Dep_Time_Hour'] = data.Dep_Time.str[0]
data['Dep_Time_Min'] = data.Dep_Time.str[1]

# %%
# Treating the arrival time column

data.Arrival_Time = data.Arrival_Time.str.split(' ')
data['Arrival_date'] = data.Arrival_Time.str[1]

# %%
data['Time_of_arrival']= data.Arrival_Time.str[0]
data['Time_of_arrival'] = data.Time_of_arrival.str.split(':')

data['Arrival_Time_Hour'] = data.Time_of_arrival.str[0]
data['Arrival_Time_Min'] = data.Time_of_arrival.str[1]

# %%
# Treating the duration column into duration_hours and duration_mins

duration=list(data['Duration'])
for i in range(len(duration)):
    if len(duration[i].split(' '))==2:
        pass
    else:
        if 'h' in duration[i]:
            duration[i]=duration[i]+ '0m'
        else:
                duration[i]= '0h' + duration[i]

# %%
def hour(x):
    return x.split(' ')[0][0:-1]

def minutes(x):
    return x.split(' ')[0][0:-1]

# %%
data['dur_hour']=data['Duration'].apply(hour)

data['dur_min']=data['Duration'].apply(minutes)

# %%
## Treating the total stop columns

data.Total_Stops.replace('non-stop','0', inplace = True)

data.Total_Stops = data.Total_Stops.str.split(' ')

data.Total_Stops = data.Total_Stops.str[0]

# %%
data.drop(['Date_of_Journey','Dep_Time','Arrival_Time','Duration','Time_of_arrival'], axis=1, inplace = True)

# %% [markdown]
# # Replacing The Misiing Values

# %%
data.head(4)
# Out:
#        Airline    Source Destination Total_Stops  Price Date Month  Year  \
# 0       IndiGo  Banglore   New Delhi           0   3897   24    03  2019
# 1    Air India   Kolkata    Banglore           2   7662    1    05  2019
# 2  Jet Airways     Delhi      Cochin           2  13882    9    06  2019
# 3       IndiGo   Kolkata    Banglore           1   6218   12    05  2019
#
#   Dep_Time_Hour Dep_Time_Min Arrival_date Arrival_Time_Hour Arrival_Time_Min  \
# 0            22           20           22                01               10
# 1            05           50          NaN                13               15
# 2            09           25           10                04               25
# 3            18           05          NaN                23               30
#
#   dur_hour dur_min
# 0        2       2
# 1        7       7
# 2       19      19
# 3        5       5

# %%
## Due to column splitting we have invited some more NAn values

data.isnull().sum()
# Out:
# Airline                 0
# Source                  0
# Destination             0
# Total_Stops             0
# Price                   0
# Date                    0
# Month                   0
# Year                    0
# Dep_Time_Hour           0
# Dep_Time_Min            0
# Arrival_date         6348
# Arrival_Time_Hour       0
# Arrival_Time_Min        0
# dur_hour                0
# dur_min                 0
# dtype: int64

# %%
## Here we are using fillna method to replace missing values


data['Total_Stops'].fillna('None', inplace = True)

data['Arrival_date'].fillna(data['Date'],inplace = True)

# %%
data
# Out:
#            Airline    Source Destination Total_Stops  Price Date Month  Year  \
# 0           IndiGo  Banglore   New Delhi           0   3897   24    03  2019
# 1        Air India   Kolkata    Banglore           2   7662    1    05  2019
# 2      Jet Airways     Delhi      Cochin           2  13882    9    06  2019
# 3           IndiGo   Kolkata    Banglore           1   6218   12    05  2019
# 4           IndiGo  Banglore   New Delhi           1  13302   01    03  2019
# ...            ...       ...         ...         ...    ...  ...   ...   ...
# 10678     Air Asia   Kolkata    Banglore           0   4107    9    04  2019
# 10679    Air India   Kolkata    Banglore           0   4145   27    04  2019
# 10680  Jet Airways  Banglore       Delhi           0   7229   27    04  2019
# 10681      Vistara  Banglore   New Delhi           0  12648   01    03  2019
# 10682    Air India     Delhi      Cochin           2  11753    9    05  2019
#
#       Dep_Time_Hour Dep_Time_Min Arrival_date Arrival_Time_Hour  \
# 0                22           20           22                01
# 1                05           50            1                13
# 2                09           25           10                04
# 3                18           05           12                23
# 4                16           50           01                21
# ...             ...          ...          ...               ...
# 10678            19           55            9                22
# 10679            20           45           27                23
# 10680            08           20           27                11
# 10681            11           30           01                14
# 10682            10           55            9                19
#
#       Arrival_Time_Min dur_hour dur_min
# 0                   10        2       2
# 1                   15        7       7
# 2                   25       19      19
# 3                   30        5       5
# 4                   35        4       4
# ...                ...      ...     ...
# 10678               25        2       2
# 10679               20        2       2
# 10680               20        3       3
# 10681               10        2       2
# 10682               15        8       8
#
# [10683 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Total_Stops        10683 non-null  object
#  4   Price              10683 non-null  int64
#  5   Date               10683 non-null  object
#  6   Month              10683 non-null  object
#  7   Year               10683 non-null  object
#  8   Dep_Time_Hour      10683 non-null  object
#  9   Dep_Time_Min       10683 non-null  object
#  10  Arrival_date       10683 non-null  object
#  11  Arrival_Time_Hour  10683 non-null  object
#  12  Arrival_Time_Min   10683 non-null  object
#  13  dur_hour           10683 non-null  object
#  14  dur_min            10683 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
data.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Price', 'Date',
#        'Month', 'Year', 'Dep_Time_Hour', 'Dep_Time_Min', 'Arrival_date',
#        'Arrival_Time_Hour', 'Arrival_Time_Min', 'dur_hour', 'dur_min'],
#       dtype='object')

# %%
data
# Out:
#            Airline    Source Destination Total_Stops  Price Date Month  Year  \
# 0           IndiGo  Banglore   New Delhi           0   3897   24    03  2019
# 1        Air India   Kolkata    Banglore           2   7662    1    05  2019
# 2      Jet Airways     Delhi      Cochin           2  13882    9    06  2019
# 3           IndiGo   Kolkata    Banglore           1   6218   12    05  2019
# 4           IndiGo  Banglore   New Delhi           1  13302   01    03  2019
# ...            ...       ...         ...         ...    ...  ...   ...   ...
# 10678     Air Asia   Kolkata    Banglore           0   4107    9    04  2019
# 10679    Air India   Kolkata    Banglore           0   4145   27    04  2019
# 10680  Jet Airways  Banglore       Delhi           0   7229   27    04  2019
# 10681      Vistara  Banglore   New Delhi           0  12648   01    03  2019
# 10682    Air India     Delhi      Cochin           2  11753    9    05  2019
#
#       Dep_Time_Hour Dep_Time_Min Arrival_date Arrival_Time_Hour  \
# 0                22           20           22                01
# 1                05           50            1                13
# 2                09           25           10                04
# 3                18           05           12                23
# 4                16           50           01                21
# ...             ...          ...          ...               ...
# 10678            19           55            9                22
# 10679            20           45           27                23
# 10680            08           20           27                11
# 10681            11           30           01                14
# 10682            10           55            9                19
#
#       Arrival_Time_Min dur_hour dur_min
# 0                   10        2       2
# 1                   15        7       7
# 2                   25       19      19
# 3                   30        5       5
# 4                   35        4       4
# ...                ...      ...     ...
# 10678               25        2       2
# 10679               20        2       2
# 10680               20        3       3
# 10681               10        2       2
# 10682               15        8       8
#
# [10683 rows x 15 columns]

# %%
data.isnull().sum().dtype
# Out:
# dtype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            10683 non-null  object
#  1   Source             10683 non-null  object
#  2   Destination        10683 non-null  object
#  3   Total_Stops        10683 non-null  object
#  4   Price              10683 non-null  int64
#  5   Date               10683 non-null  object
#  6   Month              10683 non-null  object
#  7   Year               10683 non-null  object
#  8   Dep_Time_Hour      10683 non-null  object
#  9   Dep_Time_Min       10683 non-null  object
#  10  Arrival_date       10683 non-null  object
#  11  Arrival_Time_Hour  10683 non-null  object
#  12  Arrival_Time_Min   10683 non-null  object
#  13  dur_hour           10683 non-null  object
#  14  dur_min            10683 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
data.Total_Stops.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Name: Total_Stops, Length: 10683, dtype: bool

# %%
## Changing data type of numerical columns from object to int

data.Total_Stops.astype
# Out:
# <bound method NDFrame.astype of 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10683, dtype: object>

# %% [markdown]
# # Label Encoder

# %%
data.head()
# Out:
#        Airline    Source Destination Total_Stops  Price Date Month  Year  \
# 0       IndiGo  Banglore   New Delhi           0   3897   24    03  2019
# 1    Air India   Kolkata    Banglore           2   7662    1    05  2019
# 2  Jet Airways     Delhi      Cochin           2  13882    9    06  2019
# 3       IndiGo   Kolkata    Banglore           1   6218   12    05  2019
# 4       IndiGo  Banglore   New Delhi           1  13302   01    03  2019
#
#   Dep_Time_Hour Dep_Time_Min Arrival_date Arrival_Time_Hour Arrival_Time_Min  \
# 0            22           20           22                01               10
# 1            05           50            1                13               15
# 2            09           25           10                04               25
# 3            18           05           12                23               30
# 4            16           50           01                21               35
#
#   dur_hour dur_min
# 0        2       2
# 1        7       7
# 2       19      19
# 3        5       5
# 4        4       4

# %%
data['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
Airline = data[['Airline']]

Airline = pd.get_dummies(Airline, drop_first=True)

Airline.head()
# Out:
#    Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0              False          False            True                False
# 1               True          False           False                False
# 2              False          False           False                 True
# 3              False          False            True                False
# 4              False          False            True                False
#
#    Airline_Jet Airways Business  Airline_Multiple carriers  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Airline_Multiple carriers Premium economy  Airline_SpiceJet  \
# 0                                      False             False
# 1                                      False             False
# 2                                      False             False
# 3                                      False             False
# 4                                      False             False
#
#    Airline_Trujet  Airline_Vistara  Airline_Vistara Premium economy
# 0           False            False                            False
# 1           False            False                            False
# 2           False            False                            False
# 3           False            False                            False
# 4           False            False                            False

# %%
data.Source.value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
Source = data[['Source']]

Source = pd.get_dummies(Source, drop_first=True)

Source.head()
# Out:
#    Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 0           False         False           False          False
# 1           False         False            True          False
# 2           False          True           False          False
# 3           False         False            True          False
# 4           False         False           False          False

# %%
data[['Destination']].value_counts()
# Out:
# Destination
# Cochin         4537
# Banglore       2871
# Delhi          1265
# New Delhi       932
# Hyderabad       697
# Kolkata         381
# Name: count, dtype: int64

# %%
Destination = data[['Destination']]

Destination = pd.get_dummies(Destination, drop_first=True)

Destination.head()
# Out:
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0               False              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                   True
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                   True

# %%
## Label Encoding

from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()

data.Total_Stops = lc.fit_transform(data.Total_Stops)

# %%
data= pd.concat([data, Airline,Source, Destination], axis=1)

# %%
data.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price Date Month  Year  \
# 0       IndiGo  Banglore   New Delhi            0   3897   24    03  2019
# 1    Air India   Kolkata    Banglore            2   7662    1    05  2019
# 2  Jet Airways     Delhi      Cochin            2  13882    9    06  2019
# 3       IndiGo   Kolkata    Banglore            1   6218   12    05  2019
# 4       IndiGo  Banglore   New Delhi            1  13302   01    03  2019
#
#   Dep_Time_Hour Dep_Time_Min  ... Airline_Vistara Premium economy  \
# 0            22           20  ...                           False
# 1            05           50  ...                           False
# 2            09           25  ...                           False
# 3            18           05  ...                           False
# 4            16           50  ...                           False
#
#   Source_Chennai Source_Delhi Source_Kolkata Source_Mumbai  \
# 0          False        False          False         False
# 1          False        False           True         False
# 2          False         True          False         False
# 3          False        False           True         False
# 4          False        False          False         False
#
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0               False              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                   True
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                   True
#
# [5 rows x 35 columns]

# %%
data.shape
# Out:
# (10683, 35)

# %%
data.drop(['Airline','Source','Destination'], axis=1,inplace=True)

# %%
data.head()
# Out:
#    Total_Stops  Price Date Month  Year Dep_Time_Hour Dep_Time_Min  \
# 0            0   3897   24    03  2019            22           20
# 1            2   7662    1    05  2019            05           50
# 2            2  13882    9    06  2019            09           25
# 3            1   6218   12    05  2019            18           05
# 4            1  13302   01    03  2019            16           50
#
#   Arrival_date Arrival_Time_Hour Arrival_Time_Min  ...  \
# 0           22                01               10  ...
# 1            1                13               15  ...
# 2           10                04               25  ...
# 3           12                23               30  ...
# 4           01                21               35  ...
#
#   Airline_Vistara Premium economy Source_Chennai  Source_Delhi  \
# 0                           False          False         False
# 1                           False          False         False
# 2                           False          False          True
# 3                           False          False         False
# 4                           False          False         False
#
#    Source_Kolkata  Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0           False          False               False              False
# 1            True          False               False              False
# 2           False          False                True              False
# 3            True          False               False              False
# 4           False          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 32 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Total_Stops                                10683 non-null  int64
#  1   Price                                      10683 non-null  int64
#  2   Date                                       10683 non-null  object
#  3   Month                                      10683 non-null  object
#  4   Year                                       10683 non-null  object
#  5   Dep_Time_Hour                              10683 non-null  object
#  6   Dep_Time_Min                               10683 non-null  object
#  7   Arrival_date                               10683 non-null  object
#  8   Arrival_Time_Hour                          10683 non-null  object
#  9   Arrival_Time_Min                           10683 non-null  object
#  10  dur_hour                                   10683 non-null  object
#  11  dur_min                                    10683 non-null  object
#  12  Airline_Air India                          10683 non-null  bool
#  13  Airline_GoAir                              10683 non-null  bool
#  14  Airline_IndiGo                             10683 non-null  bool
#  15  Airline_Jet Airways                        10683 non-null  bool
#  16  Airline_Jet Airways Business               10683 non-null  bool
#  17  Airline_Multiple carriers                  10683 non-null  bool
#  18  Airline_Multiple carriers Premium economy  10683 non-null  bool
#  19  Airline_SpiceJet                           10683 non-null  bool
#  20  Airline_Trujet                             10683 non-null  bool
#  21  Airline_Vistara                            10683 non-null  bool
#  22  Airline_Vistara Premium economy            10683 non-null  bool
#  23  Source_Chennai                             10683 non-null  bool
#  24  Source_Delhi                               10683 non-null  bool
#  25  Source_Kolkata                             10683 non-null  bool
#  26  Source_Mumbai                              10683 non-null  bool
#  27  Destination_Cochin                         10683 non-null  bool
#  28  Destination_Delhi                          10683 non-null  bool
#  29  Destination_Hyderabad                      10683 non-null  bool
#  30  Destination_Kolkata                        10683 non-null  bool
#  31  Destination_New Delhi                      10683 non-null  bool
# dtypes: bool(20), int64(2), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# # Feature Selection

# %%
x = data.drop(['Price'], axis=1)
x
# Out:
#        Total_Stops Date Month  Year Dep_Time_Hour Dep_Time_Min Arrival_date  \
# 0                0   24    03  2019            22           20           22
# 1                2    1    05  2019            05           50            1
# 2                2    9    06  2019            09           25           10
# 3                1   12    05  2019            18           05           12
# 4                1   01    03  2019            16           50           01
# ...            ...  ...   ...   ...           ...          ...          ...
# 10678            0    9    04  2019            19           55            9
# 10679            0   27    04  2019            20           45           27
# 10680            0   27    04  2019            08           20           27
# 10681            0   01    03  2019            11           30           01
# 10682            2    9    05  2019            10           55            9
#
#       Arrival_Time_Hour Arrival_Time_Min dur_hour  ...  \
# 0                    01               10        2  ...
# 1                    13               15        7  ...
# 2                    04               25       19  ...
# 3                    23               30        5  ...
# 4                    21               35        4  ...
# ...                 ...              ...      ...  ...
# 10678                22               25        2  ...
# 10679                23               20        2  ...
# 10680                11               20        3  ...
# 10681                14               10        2  ...
# 10682                19               15        8  ...
#
#       Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# 0                               False           False         False
# 1                               False           False         False
# 2                               False           False          True
# 3                               False           False         False
# 4                               False           False         False
# ...                               ...             ...           ...
# 10678                           False           False         False
# 10679                           False           False         False
# 10680                           False           False         False
# 10681                           False           False         False
# 10682                           False           False          True
#
#        Source_Kolkata  Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0               False          False               False              False
# 1                True          False               False              False
# 2               False          False                True              False
# 3                True          False               False              False
# 4               False          False               False              False
# ...               ...            ...                 ...                ...
# 10678            True          False               False              False
# 10679            True          False               False              False
# 10680           False          False               False               True
# 10681           False          False               False              False
# 10682           False          False                True              False
#
#        Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                      False                False                   True
# 1                      False                False                  False
# 2                      False                False                  False
# 3                      False                False                  False
# 4                      False                False                   True
# ...                      ...                  ...                    ...
# 10678                  False                False                  False
# 10679                  False                False                  False
# 10680                  False                False                  False
# 10681                  False                False                   True
# 10682                  False                False                  False
#
# [10683 rows x 31 columns]

# %%
plt.figure(figsize =(25,25))
sns.heatmap(data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
## Changing data type of numerical columns from object to int

data.Date=data.Date.astype('int64')
data.Month = data.Month.astype('int64')
data.Year = data.Year.astype('int64')
data.Dep_Time_Hour = data.Dep_Time_Hour.astype('int64')
data.Dep_Time_Min = data.Dep_Time_Min.astype('int64')
data.Arrival_date = data.Arrival_date.astype('int64')
data.Arrival_Time_Hour = data.Arrival_Time_Hour.astype('int64')
data.Arrival_Time_Min = data.Arrival_Time_Min.astype('int64')
data.dur_hour = data.dur_hour.astype('int64')
data.dur_min = data.dur_min.astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 32 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Total_Stops                                10683 non-null  int64
#  1   Price                                      10683 non-null  int64
#  2   Date                                       10683 non-null  int64
#  3   Month                                      10683 non-null  int64
#  4   Year                                       10683 non-null  int64
#  5   Dep_Time_Hour                              10683 non-null  int64
#  6   Dep_Time_Min                               10683 non-null  int64
#  7   Arrival_date                               10683 non-null  int64
#  8   Arrival_Time_Hour                          10683 non-null  int64
#  9   Arrival_Time_Min                           10683 non-null  int64
#  10  dur_hour                                   10683 non-null  int64
#  11  dur_min                                    10683 non-null  int64
#  12  Airline_Air India                          10683 non-null  bool
#  13  Airline_GoAir                              10683 non-null  bool
#  14  Airline_IndiGo                             10683 non-null  bool
#  15  Airline_Jet Airways                        10683 non-null  bool
#  16  Airline_Jet Airways Business               10683 non-null  bool
#  17  Airline_Multiple carriers                  10683 non-null  bool
#  18  Airline_Multiple carriers Premium economy  10683 non-null  bool
#  19  Airline_SpiceJet                           10683 non-null  bool
#  20  Airline_Trujet                             10683 non-null  bool
#  21  Airline_Vistara                            10683 non-null  bool
#  22  Airline_Vistara Premium economy            10683 non-null  bool
#  23  Source_Chennai                             10683 non-null  bool
#  24  Source_Delhi                               10683 non-null  bool
#  25  Source_Kolkata                             10683 non-null  bool
#  26  Source_Mumbai                              10683 non-null  bool
#  27  Destination_Cochin                         10683 non-null  bool
#  28  Destination_Delhi                          10683 non-null  bool
#  29  Destination_Hyderabad                      10683 non-null  bool
#  30  Destination_Kolkata                        10683 non-null  bool
#  31  Destination_New Delhi                      10683 non-null  bool
# dtypes: bool(20), int64(12)
# memory usage: 1.2 MB

# %% [markdown]
# # Handling Outliers

# %%
plt.figure(figsize=(25,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<20:
        ax = plt.subplot(20,3,plotnumber)
        sns.boxplot(x=data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(25,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<20:
        ax = plt.subplot(31,4,plotnumber)
        sns.boxplot(x=data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
sns.boxplot(data.Total_Stops)
# Out:
# <Axes: ylabel='Total_Stops'>

# %%
from scipy import stats

IQR = stats.iqr(data.Total_Stops, interpolation = 'midpoint')

IQR
# Out:
# 1.0

# %%
Q1 = data.Total_Stops.quantile(0.25)

Q3 = data.Total_Stops.quantile(0.75)

min_limit =  Q1 - 1.5 *IQR

max_limit = Q3 +1.5*IQR

# %%
data.shape
# Out:
# (10683, 32)

# %%
len(data.loc[data['Total_Stops']>max_limit])
# Out:
# 46

# %%
len(data.loc[data['Total_Stops']<min_limit])
# Out:
# 0

# %%
47/10683 ##total row/total lines
# Out:
# 0.004399513245343069

# %%
data.shape[0] #10683
len(data.loc[data['Total_Stops']>max_limit])
47/10683*100
# Out:
# 0.43995132453430685

# %%
data.loc[data['Total_Stops']>max_limit,'Total_Stops']=np.median(data.Total_Stops)

# %%
data.loc[data['Total_Stops']>max_limit]
# Out:
#        Total_Stops  Price  Date  Month  Year  Dep_Time_Hour  Dep_Time_Min  \
# 402              3  10493    15      6  2019              5            15
# 919              3  10991    12      5  2019             12             0
# 1218             3  11543    27      6  2019              5            15
# 1665             3  12346     1      3  2019              5            50
# 2172             3  10703    18      5  2019              5            15
# 2623             3  18293    12      3  2019              9            40
# 2633             3  21829     6      3  2019             11            35
# 2718             3  15586     9      3  2019              5            15
# 2814             3  13387    12      3  2019             17            25
# 2822             3  13007    24      5  2019             10             0
# 3157             3  16294    15      5  2019             11            35
# 3220             3  12797     6      5  2019             10             0
# 3317             3  21829     3      3  2019             11            35
# 3496             3  13387    12      3  2019              6            45
# 3568             3  14960    21      5  2019              9            50
# 3584             3  16294    15      5  2019             11            35
# 3815             3   9128    21      3  2019              5            15
# 3945             3  14260    12      3  2019             16            50
# 4118             3  10703    15      6  2019              5            15
# 4463             3  10703     1      6  2019              5            15
# 4655             3  10703    27      6  2019              5            15
# 4760             3  15629    12      6  2019             11            35
# 5050             3   8607     1      4  2019             16            45
# 5446             3  14195     6      3  2019             12             0
# 5838             3  15419    12      6  2019             11            35
# 5947             3  10573     3      3  2019             12             0
# 5996             3  15145    24      3  2019              5            55
# 6444             3  10493    24      6  2019              5            15
# 6599             3  15419     9      6  2019             11            35
# 6884             3  10703    27      6  2019              5            15
# 7001             3  14221    24      3  2019             12             0
# 7031             3  14015    12      5  2019              9            50
# 7249             3  12383     1      6  2019              5            15
# 7586             3  13007     6      5  2019              7             0
# 7752             3  15629     9      6  2019             11            35
# 7876             3  10703     6      6  2019              5            15
# 8153             3  10703     9      5  2019              5            15
# 8204             3  14960     9      6  2019              9            50
# 8601             3  10493    27      5  2019              5            15
# 8729             3  10493    24      6  2019              5            15
# 9029             3  12358     3      3  2019             12             0
# 9182             4  17686     1      3  2019              5            50
# 9454             3  12954     1      4  2019             10             0
# 9484             3   9128    21      3  2019              5            15
# 9569             3  13081     1      3  2019              5            50
# 10639            3  10493     3      6  2019              5            15
#
#        Arrival_date  Arrival_Time_Hour  Arrival_Time_Min  ...  \
# 402              16                  7                40  ...
# 919              13                 23                15  ...
# 1218             28                  7                40  ...
# 1665              2                 12                15  ...
# 2172             19                 19                15  ...
# 2623             13                 15                15  ...
# 2633              6                 21                 0  ...
# 2718             10                 19                15  ...
# 2814             13                 18                 5  ...
# 2822             25                 10                30  ...
# 3157             15                 21                 0  ...
# 3220              7                 10                30  ...
# 3317              3                 21                 0  ...
# 3496             13                 18                 5  ...
# 3568             21                 23                15  ...
# 3584             16                  1                30  ...
# 3815             22                 19                15  ...
# 3945             13                 12                25  ...
# 4118             16                 19                15  ...
# 4463              2                 19                15  ...
# 4655             28                 19                15  ...
# 4760             12                 21                 0  ...
# 5050              2                 23                15  ...
# 5446              6                 23                25  ...
# 5838             13                  1                30  ...
# 5947              3                 23                55  ...
# 5996             24                 23                15  ...
# 6444             25                  7                40  ...
# 6599             10                  1                30  ...
# 6884             28                 19                15  ...
# 7001             25                 23                15  ...
# 7031             12                 23                15  ...
# 7249              2                  7                40  ...
# 7586              7                 10                30  ...
# 7752              9                 21                 0  ...
# 7876              7                 19                15  ...
# 8153             10                 19                15  ...
# 8204              9                 23                15  ...
# 8601             28                 19                15  ...
# 8729             25                 19                15  ...
# 9029              7                 10                35  ...
# 9182              2                 11                20  ...
# 9454              2                 10                30  ...
# 9484             22                 19                15  ...
# 9569              2                  8                50  ...
# 10639             4                 19                15  ...
#
#        Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# 402                              False           False          True
# 919                              False           False         False
# 1218                             False           False          True
# 1665                             False           False         False
# 2172                             False           False          True
# 2623                             False           False         False
# 2633                             False           False          True
# 2718                             False           False          True
# 2814                             False           False         False
# 2822                             False           False         False
# 3157                             False           False          True
# 3220                             False           False         False
# 3317                             False           False          True
# 3496                             False           False         False
# 3568                             False           False         False
# 3584                             False           False          True
# 3815                             False           False          True
# 3945                             False           False         False
# 4118                             False           False          True
# 4463                             False           False          True
# 4655                             False           False          True
# 4760                             False           False          True
# 5050                             False           False         False
# 5446                             False           False         False
# 5838                             False           False          True
# 5947                             False           False         False
# 5996                             False           False         False
# 6444                             False           False          True
# 6599                             False           False          True
# 6884                             False           False          True
# 7001                             False           False         False
# 7031                             False           False         False
# 7249                             False           False          True
# 7586                             False           False         False
# 7752                             False           False          True
# 7876                             False           False          True
# 8153                             False           False          True
# 8204                             False           False         False
# 8601                             False           False          True
# 8729                             False           False          True
# 9029                             False           False         False
# 9182                             False           False         False
# 9454                             False           False         False
# 9484                             False           False          True
# 9569                             False           False         False
# 10639                            False           False          True
#
#        Source_Kolkata  Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 402             False          False                True              False
# 919              True          False               False              False
# 1218            False          False                True              False
# 1665            False          False               False              False
# 2172            False          False                True              False
# 2623            False           True               False              False
# 2633            False          False                True              False
# 2718            False          False                True              False
# 2814            False          False               False              False
# 2822             True          False               False              False
# 3157            False          False                True              False
# 3220             True          False               False              False
# 3317            False          False                True              False
# 3496            False          False               False              False
# 3568             True          False               False              False
# 3584            False          False                True              False
# 3815            False          False                True              False
# 3945            False           True               False              False
# 4118            False          False                True              False
# 4463            False          False                True              False
# 4655            False          False                True              False
# 4760            False          False                True              False
# 5050             True          False               False              False
# 5446            False          False               False              False
# 5838            False          False                True              False
# 5947            False          False               False              False
# 5996             True          False               False              False
# 6444            False          False                True              False
# 6599            False          False                True              False
# 6884            False          False                True              False
# 7001             True          False               False              False
# 7031             True          False               False              False
# 7249            False          False                True              False
# 7586             True          False               False              False
# 7752            False          False                True              False
# 7876            False          False                True              False
# 8153            False          False                True              False
# 8204             True          False               False              False
# 8601            False          False                True              False
# 8729            False          False                True              False
# 9029            False          False               False              False
# 9182            False          False               False              False
# 9454             True          False               False              False
# 9484            False          False                True              False
# 9569            False          False               False              False
# 10639           False          False                True              False
#
#        Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 402                    False                False                  False
# 919                    False                False                  False
# 1218                   False                False                  False
# 1665                   False                False                   True
# 2172                   False                False                  False
# 2623                    True                False                  False
# 2633                   False                False                  False
# 2718                   False                False                  False
# 2814                   False                False                   True
# 2822                   False                False                  False
# 3157                   False                False                  False
# 3220                   False                False                  False
# 3317                   False                False                  False
# 3496                   False                False                   True
# 3568                   False                False                  False
# 3584                   False                False                  False
# 3815                   False                False                  False
# 3945                    True                False                  False
# 4118                   False                False                  False
# 4463                   False                False                  False
# 4655                   False                False                  False
# 4760                   False                False                  False
# 5050                   False                False                  False
# 5446                   False                False                   True
# 5838                   False                False                  False
# 5947                   False                False                   True
# 5996                   False                False                  False
# 6444                   False                False                  False
# 6599                   False                False                  False
# 6884                   False                False                  False
# 7001                   False                False                  False
# 7031                   False                False                  False
# 7249                   False                False                  False
# 7586                   False                False                  False
# 7752                   False                False                  False
# 7876                   False                False                  False
# 8153                   False                False                  False
# 8204                   False                False                  False
# 8601                   False                False                  False
# 8729                   False                False                  False
# 9029                   False                False                   True
# 9182                   False                False                   True
# 9454                   False                False                  False
# 9484                   False                False                  False
# 9569                   False                False                   True
# 10639                  False                False                  False
#
# [46 rows x 32 columns]

# %%
sns.boxplot(data.Total_Stops)
# Out:
# <Axes: ylabel='Total_Stops'>

# %%
sns.boxplot(data.dur_hour)
# Out:
# <Axes: ylabel='dur_hour'>

# %%
IQR = stats.iqr(data.dur_hour, interpolation = 'midpoint')

IQR
# Out:
# 13.0

# %%
Q1 = data.dur_hour.quantile(0.25)

Q3 = data.dur_hour.quantile(0.75)

min_limit = Q1 - 1.5*IQR

max_limit = Q3 + 1.5*IQR

# %%
min_limit
# Out:
# -17.5

# %%
max_limit
# Out:
# 34.5

# %%
len(data.loc[data['dur_hour']>max_limit])
# Out:
# 73

# %%
data.shape[0] #10683
len(data.loc[data['dur_hour']>max_limit])
73/10683*100
# Out:
# 0.6833286530000936

# %%
data.loc[data['dur_hour']>max_limit,'dur_hour']=np.median(data.dur_hour)

# %%
data.loc[data['dur_hour']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Total_Stops, Price, Date, Month, Year, Dep_Time_Hour, Dep_Time_Min, Arrival_date, Arrival_Time_Hour, Arrival_Time_Min, dur_hour, dur_min, Airline_Air India, Airline_GoAir, Airline_IndiGo, Airline_Jet Airways, Airline_Jet Airways Business, Airline_Multiple carriers, Airline_Multiple carriers Premium economy, Airline_SpiceJet, Airline_Trujet, Airline_Vistara, Airline_Vistara Premium economy, Source_Chennai, Source_Delhi, Source_Kolkata, Source_Mumbai, Destination_Cochin, Destination_Delhi, Destination_Hyderabad, Destination_Kolkata, Destination_New Delhi]
# Index: []
#
# [0 rows x 32 columns]

# %%
sns.boxplot(data.dur_hour)
# Out:
# <Axes: ylabel='dur_hour'>

# %%
sns.boxplot(data.dur_min)
# Out:
# <Axes: ylabel='dur_min'>

# %%
QR = stats.iqr(data.dur_min, interpolation = 'midpoint')

IQR
# Out:
# 13.0

# %%
Q1 = data.dur_hour.quantile(0.25)

Q3 = data.dur_hour.quantile(0.75)

min_limit = Q1 - 1.5*IQR

max_limit = Q3 + 1.5*IQR

# %%
min_limit
# Out:
# -17.5

# %%
max_limit
# Out:
# 34.5

# %%
len(data.loc[data['dur_min']>max_limit])
# Out:
# 73

# %%
data.shape[0] #10683
len(data.loc[data['dur_hour']>max_limit])
73/10683*100
# Out:
# 0.6833286530000936

# %%
data.loc[data['dur_min']>max_limit,'dur_min']=np.median(data.dur_min)

# %%
data.loc[data['dur_min']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Total_Stops, Price, Date, Month, Year, Dep_Time_Hour, Dep_Time_Min, Arrival_date, Arrival_Time_Hour, Arrival_Time_Min, dur_hour, dur_min, Airline_Air India, Airline_GoAir, Airline_IndiGo, Airline_Jet Airways, Airline_Jet Airways Business, Airline_Multiple carriers, Airline_Multiple carriers Premium economy, Airline_SpiceJet, Airline_Trujet, Airline_Vistara, Airline_Vistara Premium economy, Source_Chennai, Source_Delhi, Source_Kolkata, Source_Mumbai, Destination_Cochin, Destination_Delhi, Destination_Hyderabad, Destination_Kolkata, Destination_New Delhi]
# Index: []
#
# [0 rows x 32 columns]

# %%
sns.boxplot(data.dur_min)
# Out:
# <Axes: ylabel='dur_min'>
